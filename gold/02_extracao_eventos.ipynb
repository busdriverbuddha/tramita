# %% [markdown]
# # 2. Extração de eventos de tramitação no Congresso

# %% [markdown]
# Neste notebook, vamos extrair do banco de dados os eventos de tramitação, isto é, etapas que sinalizem o avanço de uma proposição no processo legislativo, p. ex. quando uma proposição é recebida por comissão ou votada em plenário.

# %% [markdown]
# ## 2.1. Preparação

# %% [markdown]
# ### 2.1.1. Imports

# %%
import json
import os
import re

from pathlib import Path

import duckdb
import pandas as pd

from tramita.gold import Event  # Enum customizado nosso para eventos relevantes de tramitação

from dotenv import load_dotenv

load_dotenv()

PROJECT_DIR = Path("~/tramita").expanduser()
DB_PATH = PROJECT_DIR / os.getenv("SILVER_DUCKDB_PATH", "")
OUT_DIR = PROJECT_DIR / "gold" / "outputs"
OUT_DIR.mkdir(exist_ok=True)
ACCESS_DIR = PROJECT_DIR / "gold" / "accessory_data"
ACCESS_DIR.mkdir(exist_ok=True)

PARQUET_ROOT = PROJECT_DIR / "data" / "bronze" / "snapshots" / "bronze-2020-2024-v2"

NODES_PATH_CSV = OUT_DIR / "nodes.csv"
EDGES_PATH_CSV = OUT_DIR / "edges.csv"

# %% [markdown]
# ### 2.1.2. Leitura do banco de dados
#
# Aqui carregamos os dados da fase prata. Em todas as tabelas exceto uma, adotamos o ID natural como índice, para que essas tabelas possam ser alvo de *joins*. Apenas para a tabela de tramitações isso não é necessário, já que ela será a base para a construção da tabela final de eventos e seu índice será desprezado.

# %%
with duckdb.connect(DB_PATH, read_only=True) as con:
    # Câmara
    ## Proposições
    house_props_df = con.execute("SELECT * FROM proposicoes_camara").df().set_index('id_proposicao', drop=True)
    ## Órgãos
    house_orgaos_df = con.execute("SELECT * FROM orgaos_camara").df().set_index('id_orgao', drop=True)
    ## Tramitações
    house_tram_df = con.execute("SELECT * FROM tramitacoes_camara").df()
    
    # Senado
    ## Processos
    senate_procs_df = con.execute("SELECT * FROM processo_senado").df().set_index('id_processo', drop=True)
    
    ## Despachos
    senate_desp_df = con.execute("SELECT * FROM despachos_senado").df().set_index('id_despacho', drop=True)
    
    ## Providências
    senate_prov_df = con.execute("SELECT * FROM providencias_senado").df().set_index('id_providencia', drop=True)
    
    ## Informes legislativos
    senate_inf_df = con.execute("SELECT * FROM informes_legislativos_senado").df().set_index('id_informe_legislativo', drop=True)
    
    ## Unidades destinatárias
    senate_unid_df = con.execute("SELECT * FROM unidades_destinatarias_senado").df().set_index('id_unidade_destinataria', drop=True)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %% [markdown]
# ### 2.1.3. Seleção dos dados relevantes à nossa análise

# %% [markdown]
# Primeiro recuperamos os IDs relevantes de proposições e processos do grafo que construímos na parte 1.

# %%
nodes_df = pd.read_csv(NODES_PATH_CSV)
prop_ids = nodes_df[nodes_df['type'].eq('Proposicao')]['tag'].str.split(":", expand=True)[1].astype(int).to_list()
proc_ids = nodes_df[nodes_df['type'].eq('Processo')]['tag'].str.split(":", expand=True)[1].astype(int).to_list()

# %% [markdown]
# Então selecionamos os dados de tramitação pertinentes somente a essas IDs.

# %%
house_tram_df = house_tram_df[
    house_tram_df['id_proposicao'].isin(prop_ids)
].copy().set_index('id_tramitacao', drop=True)

def filter_by_processo(df):
    return df[df['id_processo'].isin(proc_ids)]

senate_desp_df = filter_by_processo(senate_desp_df)
senate_prov_df = filter_by_processo(senate_prov_df)
senate_inf_df = filter_by_processo(senate_inf_df)
senate_unid_df = filter_by_processo(senate_unid_df)

# %% [markdown]
# Cabe observar que não vamos filtrar os órgãos da Câmara, uma vez que podem figurar também como locais onde tramitações ocorrem (ex. Comissões, Plenário).

# %% [markdown]
# ## 2.2. Construção da tabela de tramitações
#
# A partir daqui vamos executar uma série de passos para construir uma tabela completa com as tramitações de cada proposição em cada casa.

# %% [markdown]
# ### 2.2.1. Câmara dos Deputados
#
# Primeiro fazemos um join com a tabela de vértices para recuperar os nomes das proposições.

# %%
house_tram_df['id_proposicao'].isna().any()
# Out:
# np.False_

# %% [markdown]
# Derivamos a tabela de *tags* para compatibilizar com nossos vértices.

# %%
house_tram_df['prop_tag'] = "CP:" + house_tram_df['id_proposicao'].astype(str)
house_tram_df
# Out:
#                id_proposicao      ambito  \
# id_tramitacao
# 462                   538196  Regimental
# 545                   559138  Regimental
# 647                   593065  Regimental
# 687                   601739  Regimental
# 744                   614512  Regimental
# ...                      ...         ...
# 880670               2466104  Regimental
# 880671               2466104  Regimental
# 880672               2466104  Regimental
# 880673               2466104  Regimental
# 880674               2466104  Regimental
#
#                                                 apreciacao cod_situacao  \
# id_tramitacao
# 462            Proposição Sujeita à Apreciação do Plenário         1140
# 545            Proposição Sujeita à Apreciação do Plenário         1140
# 647            Proposição Sujeita à Apreciação do Plenário         1140
# 687            Proposição Sujeita à Apreciação do Plenário          924
# 744            Proposição Sujeita à Apreciação do Plenário         1140
# ...                                                    ...          ...
# 880670         Proposição Sujeita à Apreciação do Plenário         1140
# 880671         Proposição Sujeita à Apreciação do Plenário         1140
# 880672         Proposição Sujeita à Apreciação do Plenário         None
# 880673         Proposição Sujeita à Apreciação do Plenário         None
# 880674         Proposição Sujeita à Apreciação do Plenário         1140
#
#               cod_tipo_tramitacao           data_hora  \
# id_tramitacao
# 462                           100 2021-11-17 00:00:00
# 545                           100 2025-05-05 00:00:00
# 647                           100 2021-11-17 00:00:00
# 687                           501 2024-12-02 18:35:00
# 744                           500 2022-07-15 00:00:00
# ...                           ...                 ...
# 880670                        194 2024-11-04 14:35:00
# 880671                        110 2024-11-04 13:13:00
# 880672                        604 2024-11-04 00:00:00
# 880673                        320 2024-11-02 00:00:00
# 880674                        100 2024-10-31 09:41:00
#
#                            descricao_situacao          descricao_tramitacao  \
# id_tramitacao
# 462            Transformado em Norma Jurídica    Apresentação de Proposição
# 545            Transformado em Norma Jurídica    Apresentação de Proposição
# 647            Transformado em Norma Jurídica    Apresentação de Proposição
# 687                         Pronta para Pauta      Recebimento - Relator(a)
# 744            Transformado em Norma Jurídica                   Recebimento
# ...                                       ...                           ...
# 880670         Transformado em Norma Jurídica  Apresentação de Requerimento
# 880671         Transformado em Norma Jurídica                  Distribuição
# 880672                                   None      Publicação de Proposição
# 880673                                   None      Designação de Relator(a)
# 880674         Transformado em Norma Jurídica    Apresentação de Proposição
#
#                                                         despacho  \
# id_tramitacao
# 462            Ofício nº 205/2021/PS-GSE ao Senado Federal, i...
# 545            Apresentação do Of. nº 10 /2024/PS-GSE, que co...
# 647            Ofício nº  201/2021/PS-GSE ao Senado Federal, ...
# 687            Apresentação do PRL n. 1 CAPADR (Parecer do Re...
# 744            Recebimento do Ofício nº 306/2022 (CN) encamin...
# ...                                                          ...
# 880670         Apresentação do REQ n. 4403/2024 (Requerimento...
# 880671         Às Comissões de Administração e Serviço Públic...
# 880672         Encaminhada à publicação. Publicação Inicial e...
# 880673         Designado Relator, Dep. Elmar Nascimento (UNIÃ...
# 880674         Apresentação do PLP n. 175/2024 (Projeto de Le...
#
#                                         regime  sequencia sigla_orgao  \
# id_tramitacao
# 462                  Urgência (Art. 155, RICD)        213        MESA
# 545                  Urgência (Art. 155, RICD)        262        MESA
# 647                  Urgência (Art. 155, RICD)        322        MESA
# 687            Ordinário (Art. 151, III, RICD)        136      CAPADR
# 744                  Urgência (Art. 155, RICD)        203        MESA
# ...                                        ...        ...         ...
# 880670               Urgência (Art. 155, RICD)         13        MESA
# 880671               Urgência (Art. 155, RICD)          8        MESA
# 880672               Urgência (Art. 155, RICD)         14         CCP
# 880673               Urgência (Art. 155, RICD)          7        PLEN
# 880674               Urgência (Art. 155, RICD)          1        MESA
#
#                                                        uri_orgao  \
# id_tramitacao
# 462            https://dadosabertos.camara.leg.br/api/v2/orga...
# 545            https://dadosabertos.camara.leg.br/api/v2/orga...
# 647            https://dadosabertos.camara.leg.br/api/v2/orga...
# 687            https://dadosabertos.camara.leg.br/api/v2/orga...
# 744            https://dadosabertos.camara.leg.br/api/v2/orga...
# ...                                                          ...
# 880670         https://dadosabertos.camara.leg.br/api/v2/orga...
# 880671         https://dadosabertos.camara.leg.br/api/v2/orga...
# 880672         https://dadosabertos.camara.leg.br/api/v2/orga...
# 880673         https://dadosabertos.camara.leg.br/api/v2/orga...
# 880674         https://dadosabertos.camara.leg.br/api/v2/orga...
#
#                                               uri_ultimo_relator  \
# id_tramitacao
# 462            https://dadosabertos.camara.leg.br/api/v2/depu...
# 545            https://dadosabertos.camara.leg.br/api/v2/depu...
# 647            https://dadosabertos.camara.leg.br/api/v2/depu...
# 687            https://dadosabertos.camara.leg.br/api/v2/depu...
# 744            https://dadosabertos.camara.leg.br/api/v2/depu...
# ...                                                          ...
# 880670         https://dadosabertos.camara.leg.br/api/v2/depu...
# 880671         https://dadosabertos.camara.leg.br/api/v2/depu...
# 880672         https://dadosabertos.camara.leg.br/api/v2/depu...
# 880673         https://dadosabertos.camara.leg.br/api/v2/depu...
# 880674                                                      None
#
#                year_snapshot    prop_tag
# id_tramitacao
# 462                     2020   CP:538196
# 545                     2020   CP:559138
# 647                     2020   CP:593065
# 687                     2020   CP:601739
# 744                     2020   CP:614512
# ...                      ...         ...
# 880670                  2024  CP:2466104
# 880671                  2024  CP:2466104
# 880672                  2024  CP:2466104
# 880673                  2024  CP:2466104
# 880674                  2024  CP:2466104
#
# [387132 rows x 16 columns]

# %% [markdown]
# Fazemos um *join* com a tabela de vértices para recuperar os nomes das proposições (p. ex. PL 2597/2024).

# %%
house_tram_expanded_df = house_tram_df.join(
    nodes_df.set_index('tag', drop=True)['label'],
    on="prop_tag",
    how="left",
)[[
    'id_proposicao',
    'label',
    'sequencia',
    'data_hora',
    'descricao_tramitacao',
    'sigla_orgao',
    'despacho',
    'cod_situacao',
    'descricao_situacao',
    'regime',
    'apreciacao',
    'cod_tipo_tramitacao',
    'uri_orgao',
]].sort_values(['id_proposicao', 'data_hora']).rename(columns={'label': 'prop_label'})
house_tram_expanded_df
# Out:
#                id_proposicao    prop_label  sequencia           data_hora  \
# id_tramitacao
# 771001                253500  PL 2597/2024          1 2004-05-13 14:41:00
# 771000                253500  PL 2597/2024          6 2004-05-14 10:46:00
# 770999                253500  PL 2597/2024         12 2004-05-28 11:08:00
# 770998                253500  PL 2597/2024         17 2004-06-01 00:00:00
# 770997                253500  PL 2597/2024         18 2004-06-02 09:45:00
# ...                      ...           ...        ...                 ...
# 875892               2531284  PL 3194/2025          2 2025-07-02 14:10:00
# 875352               2531284  PL 3194/2025          8 2025-08-29 14:45:00
# 874734               2531284  PL 3194/2025         14 2025-09-02 00:00:00
# 874104               2531284  PL 3194/2025         15 2025-09-04 11:18:00
# 873280               2531284  PL 3194/2025         16 2025-09-04 11:22:00
#
#                      descricao_tramitacao sigla_orgao  \
# id_tramitacao
# 771001         Apresentação de Proposição        PLEN
# 771000                        Recebimento  SECAP(SGM)
# 770999                       Distribuição        MESA
# 770998           Publicação de Proposição         CCP
# 770997                        Recebimento         CDE
# ...                                   ...         ...
# 875892         Apresentação de Proposição        MESA
# 875352              Despacho de Apensação        MESA
# 874734           Publicação de Proposição         CCP
# 874104                        Recebimento         CDC
# 873280                          Apensação         CDC
#
#                                                         despacho cod_situacao  \
# id_tramitacao
# 771001         Apresentação do Projeto de Lei pelo Dep. José ...         None
# 771000                                    Recebimento pela MESA.         None
# 770999         Às Comissões de Desenvolvimento Econômico, Ind...         1140
# 770998         Encaminhada à publicação. Publicação Inicial n...         None
# 770997                                   Recebimento pela CDEIC.         None
# ...                                                          ...          ...
# 875892         Apresentação do PL n. 3194/2025 (Projeto de Le...         None
# 875352         Apense-se à(ao) PL-4348/2024.Proposição Sujeit...         None
# 874734         Encaminhada à publicação. Publicação Inicial e...         None
# 874104                                  Recebimento pelo(a) CDC.          925
# 873280               Apensação desta proposição ao PL 4348/2024.          925
#
#                            descricao_situacao  \
# id_tramitacao
# 771001                                   None
# 771000                                   None
# 770999         Transformado em Norma Jurídica
# 770998                                   None
# 770997                                   None
# ...                                       ...
# 875892                                   None
# 875352                                   None
# 874734                                   None
# 874104                 Tramitando em Conjunto
# 873280                 Tramitando em Conjunto
#
#                                         regime  \
# id_tramitacao
# 771001               Urgência (Art. 155, RICD)
# 771000               Urgência (Art. 155, RICD)
# 770999               Urgência (Art. 155, RICD)
# 770998               Urgência (Art. 155, RICD)
# 770997               Urgência (Art. 155, RICD)
# ...                                        ...
# 875892         Ordinário (Art. 151, III, RICD)
# 875352         Ordinário (Art. 151, III, RICD)
# 874734         Ordinário (Art. 151, III, RICD)
# 874104         Ordinário (Art. 151, III, RICD)
# 873280         Ordinário (Art. 151, III, RICD)
#
#                                                       apreciacao  \
# id_tramitacao
# 771001               Proposição Sujeita à Apreciação do Plenário
# 771000               Proposição Sujeita à Apreciação do Plenário
# 770999               Proposição Sujeita à Apreciação do Plenário
# 770998               Proposição Sujeita à Apreciação do Plenário
# 770997               Proposição Sujeita à Apreciação do Plenário
# ...                                                          ...
# 875892         Proposição Sujeita à Apreciação Conclusiva pel...
# 875352         Proposição Sujeita à Apreciação Conclusiva pel...
# 874734         Proposição Sujeita à Apreciação Conclusiva pel...
# 874104         Proposição Sujeita à Apreciação Conclusiva pel...
# 873280         Proposição Sujeita à Apreciação Conclusiva pel...
#
#               cod_tipo_tramitacao  \
# id_tramitacao
# 771001                        100
# 771000                        500
# 770999                        110
# 770998                        604
# 770997                        500
# ...                           ...
# 875892                        100
# 875352                        129
# 874734                        604
# 874104                        500
# 873280                        106
#
#                                                        uri_orgao
# id_tramitacao
# 771001         https://dadosabertos.camara.leg.br/api/v2/orga...
# 771000         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770999         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770998         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770997         https://dadosabertos.camara.leg.br/api/v2/orga...
# ...                                                          ...
# 875892         https://dadosabertos.camara.leg.br/api/v2/orga...
# 875352         https://dadosabertos.camara.leg.br/api/v2/orga...
# 874734         https://dadosabertos.camara.leg.br/api/v2/orga...
# 874104         https://dadosabertos.camara.leg.br/api/v2/orga...
# 873280         https://dadosabertos.camara.leg.br/api/v2/orga...
#
# [387132 rows x 13 columns]

# %% [markdown]
# Juntamos a isso os nomes e tipos dos órgãos, fazendo um *join* com a tabela de órgãos da Câmara.

# %%
house_tram_expanded_df = house_tram_expanded_df.join(
    house_orgaos_df.set_index('uri')[['cod_tipo_orgao', 'nome']],
    on="uri_orgao",
    how="left",
).rename(columns={'nome': 'nome_orgao'}).copy()
house_tram_expanded_df['data_hora'] = pd.to_datetime(house_tram_expanded_df['data_hora'])
house_tram_expanded_df
# Out:
#                id_proposicao    prop_label  sequencia           data_hora  \
# id_tramitacao
# 771001                253500  PL 2597/2024          1 2004-05-13 14:41:00
# 771000                253500  PL 2597/2024          6 2004-05-14 10:46:00
# 770999                253500  PL 2597/2024         12 2004-05-28 11:08:00
# 770998                253500  PL 2597/2024         17 2004-06-01 00:00:00
# 770997                253500  PL 2597/2024         18 2004-06-02 09:45:00
# ...                      ...           ...        ...                 ...
# 875892               2531284  PL 3194/2025          2 2025-07-02 14:10:00
# 875352               2531284  PL 3194/2025          8 2025-08-29 14:45:00
# 874734               2531284  PL 3194/2025         14 2025-09-02 00:00:00
# 874104               2531284  PL 3194/2025         15 2025-09-04 11:18:00
# 873280               2531284  PL 3194/2025         16 2025-09-04 11:22:00
#
#                      descricao_tramitacao sigla_orgao  \
# id_tramitacao
# 771001         Apresentação de Proposição        PLEN
# 771000                        Recebimento  SECAP(SGM)
# 770999                       Distribuição        MESA
# 770998           Publicação de Proposição         CCP
# 770997                        Recebimento         CDE
# ...                                   ...         ...
# 875892         Apresentação de Proposição        MESA
# 875352              Despacho de Apensação        MESA
# 874734           Publicação de Proposição         CCP
# 874104                        Recebimento         CDC
# 873280                          Apensação         CDC
#
#                                                         despacho cod_situacao  \
# id_tramitacao
# 771001         Apresentação do Projeto de Lei pelo Dep. José ...         None
# 771000                                    Recebimento pela MESA.         None
# 770999         Às Comissões de Desenvolvimento Econômico, Ind...         1140
# 770998         Encaminhada à publicação. Publicação Inicial n...         None
# 770997                                   Recebimento pela CDEIC.         None
# ...                                                          ...          ...
# 875892         Apresentação do PL n. 3194/2025 (Projeto de Le...         None
# 875352         Apense-se à(ao) PL-4348/2024.Proposição Sujeit...         None
# 874734         Encaminhada à publicação. Publicação Inicial e...         None
# 874104                                  Recebimento pelo(a) CDC.          925
# 873280               Apensação desta proposição ao PL 4348/2024.          925
#
#                            descricao_situacao  \
# id_tramitacao
# 771001                                   None
# 771000                                   None
# 770999         Transformado em Norma Jurídica
# 770998                                   None
# 770997                                   None
# ...                                       ...
# 875892                                   None
# 875352                                   None
# 874734                                   None
# 874104                 Tramitando em Conjunto
# 873280                 Tramitando em Conjunto
#
#                                         regime  \
# id_tramitacao
# 771001               Urgência (Art. 155, RICD)
# 771000               Urgência (Art. 155, RICD)
# 770999               Urgência (Art. 155, RICD)
# 770998               Urgência (Art. 155, RICD)
# 770997               Urgência (Art. 155, RICD)
# ...                                        ...
# 875892         Ordinário (Art. 151, III, RICD)
# 875352         Ordinário (Art. 151, III, RICD)
# 874734         Ordinário (Art. 151, III, RICD)
# 874104         Ordinário (Art. 151, III, RICD)
# 873280         Ordinário (Art. 151, III, RICD)
#
#                                                       apreciacao  \
# id_tramitacao
# 771001               Proposição Sujeita à Apreciação do Plenário
# 771000               Proposição Sujeita à Apreciação do Plenário
# 770999               Proposição Sujeita à Apreciação do Plenário
# 770998               Proposição Sujeita à Apreciação do Plenário
# 770997               Proposição Sujeita à Apreciação do Plenário
# ...                                                          ...
# 875892         Proposição Sujeita à Apreciação Conclusiva pel...
# 875352         Proposição Sujeita à Apreciação Conclusiva pel...
# 874734         Proposição Sujeita à Apreciação Conclusiva pel...
# 874104         Proposição Sujeita à Apreciação Conclusiva pel...
# 873280         Proposição Sujeita à Apreciação Conclusiva pel...
#
#               cod_tipo_tramitacao  \
# id_tramitacao
# 771001                        100
# 771000                        500
# 770999                        110
# 770998                        604
# 770997                        500
# ...                           ...
# 875892                        100
# 875352                        129
# 874734                        604
# 874104                        500
# 873280                        106
#
#                                                        uri_orgao  \
# id_tramitacao
# 771001         https://dadosabertos.camara.leg.br/api/v2/orga...
# 771000         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770999         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770998         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770997         https://dadosabertos.camara.leg.br/api/v2/orga...
# ...                                                          ...
# 875892         https://dadosabertos.camara.leg.br/api/v2/orga...
# 875352         https://dadosabertos.camara.leg.br/api/v2/orga...
# 874734         https://dadosabertos.camara.leg.br/api/v2/orga...
# 874104         https://dadosabertos.camara.leg.br/api/v2/orga...
# 873280         https://dadosabertos.camara.leg.br/api/v2/orga...
#
#                cod_tipo_orgao  \
# id_tramitacao
# 771001                     26
# 771000                  12000
# 770999                      1
# 770998                  12000
# 770997                      2
# ...                       ...
# 875892                      1
# 875352                      1
# 874734                  12000
# 874104                      2
# 873280                      2
#
#                                                       nome_orgao
# id_tramitacao
# 771001                                                  Plenário
# 771000         Seção de Registro e Controle de Análise da Pro...
# 770999                     Mesa Diretora da Câmara dos Deputados
# 770998                      COORDENAÇÃO DE COMISSÕES PERMANENTES
# 770997                     Comissão de Desenvolvimento Econômico
# ...                                                          ...
# 875892                     Mesa Diretora da Câmara dos Deputados
# 875352                     Mesa Diretora da Câmara dos Deputados
# 874734                      COORDENAÇÃO DE COMISSÕES PERMANENTES
# 874104                          Comissão de Defesa do Consumidor
# 873280                          Comissão de Defesa do Consumidor
#
# [387132 rows x 15 columns]

# %% [markdown]
# Precisamos também dos nomes dos tipos de órgãos. Isso temos da fase bronze.

# %%
payloads_str = pd.read_parquet(
    PARQUET_ROOT / "camara" / "referencias" / "orgaos_codTipoOrgao",
)['payload_json'].to_list()
payloads = list(map(json.loads, payloads_str))

house_tipo_orgao_df = (
    pd.DataFrame(payloads)[['cod', 'nome']]
        .rename(columns={'cod': 'cod_tipo_orgao', 'nome': 'tipo_orgao'})
)
house_tipo_orgao_df['cod_tipo_orgao'] = house_tipo_orgao_df['cod_tipo_orgao'].astype(int)
house_tipo_orgao_df['tipo_orgao'] = house_tipo_orgao_df['tipo_orgao'].astype(str)
house_tipo_orgao_df = house_tipo_orgao_df.set_index('cod_tipo_orgao', drop=True)
house_tipo_orgao_df
# Out:
#                                               tipo_orgao
# cod_tipo_orgao
# 1                                      Comissão Diretora
# 2                                    Comissão Permanente
# 3                                      Comissão Especial
# 4                      Comissão Parlamentar de Inquérito
# 5                                       Comissão Externa
# 6                              Comissão Mista Permanente
# 7                                Comissão de Sindicância
# 8                          Comissão Representativa do CN
# 9                             Comissão Medida Provisória
# 10                                     Grupo de Trabalho
# 11                                              Conselho
# 12                              Procuradoria Parlamentar
# 13                                          Corregedoria
# 14                                             Ouvidoria
# 15                               COORDENADORIA DA MULHER
# 20               Comissão Parlamentar Mista de Inquérito
# 21                               Comissão Mista Especial
# 22                                           Conferência
# 25                                           Subcomissão
# 26                                      Plenário Virtual
# 27                                   Plenário Virtual CD
# 28                        GRUPO DE TRABALHO DE COMISSÕES
# 101                                     Partido Político
# 102                                    Bloco Parlamentar
# 103                                        Governo na CD
# 104                                        Minoria na CD
# 105                                        Governo no CN
# 106                                        Minoria no CN
# 110                     Comissão da Câmara dos Deputados
# 121                                        Maioria na CD
# 122                                       Oposição na CD
# 123                                        Maioria no CN
# 124                                       Oposição no CN
# 200                                           TEMPORÁRIA
# 1000                 Importação das proposições inativas
# 12000                      Órgão da Câmara dos Deputados
# 12500                            Órgão Legislativo da CD
# 13000                          Comissão Temporária da CD
# 21000                         Comissão do Senado Federal
# 22000                            Órgão do Senado Federal
# 30000                           Órgão do Poder Executivo
# 40000                         Órgão do Poder Legislativo
# 50000                          Órgão do Poder Judiciário
# 70000                                    Sociedade Civil
# 80000                                          Liderança
# 81000                                            Bancada
# 81001                        Órgão do Congresso Nacional
# 81002                                     Comissão Mista
# 81003              Comissão Permanente do Senado Federal
# 81004              Comissão Temporária do Senado Federal
# 81005                               Gabinete Parlamentar
# 81006           Órgão Remessa Requerimento de Informação
# 81007                  MPU - Ministério Público da União
# 81008                  DPU - Defensoria Pública da União
# 81009                                   Partido Político

# %% [markdown]
# E juntamos isso também à tabela de tramitações.

# %%
house_tram_expanded_df = house_tram_expanded_df.join(
    house_tipo_orgao_df,
    on="cod_tipo_orgao",
)
house_tram_expanded_df
# Out:
#                id_proposicao    prop_label  sequencia           data_hora  \
# id_tramitacao
# 771001                253500  PL 2597/2024          1 2004-05-13 14:41:00
# 771000                253500  PL 2597/2024          6 2004-05-14 10:46:00
# 770999                253500  PL 2597/2024         12 2004-05-28 11:08:00
# 770998                253500  PL 2597/2024         17 2004-06-01 00:00:00
# 770997                253500  PL 2597/2024         18 2004-06-02 09:45:00
# ...                      ...           ...        ...                 ...
# 875892               2531284  PL 3194/2025          2 2025-07-02 14:10:00
# 875352               2531284  PL 3194/2025          8 2025-08-29 14:45:00
# 874734               2531284  PL 3194/2025         14 2025-09-02 00:00:00
# 874104               2531284  PL 3194/2025         15 2025-09-04 11:18:00
# 873280               2531284  PL 3194/2025         16 2025-09-04 11:22:00
#
#                      descricao_tramitacao sigla_orgao  \
# id_tramitacao
# 771001         Apresentação de Proposição        PLEN
# 771000                        Recebimento  SECAP(SGM)
# 770999                       Distribuição        MESA
# 770998           Publicação de Proposição         CCP
# 770997                        Recebimento         CDE
# ...                                   ...         ...
# 875892         Apresentação de Proposição        MESA
# 875352              Despacho de Apensação        MESA
# 874734           Publicação de Proposição         CCP
# 874104                        Recebimento         CDC
# 873280                          Apensação         CDC
#
#                                                         despacho cod_situacao  \
# id_tramitacao
# 771001         Apresentação do Projeto de Lei pelo Dep. José ...         None
# 771000                                    Recebimento pela MESA.         None
# 770999         Às Comissões de Desenvolvimento Econômico, Ind...         1140
# 770998         Encaminhada à publicação. Publicação Inicial n...         None
# 770997                                   Recebimento pela CDEIC.         None
# ...                                                          ...          ...
# 875892         Apresentação do PL n. 3194/2025 (Projeto de Le...         None
# 875352         Apense-se à(ao) PL-4348/2024.Proposição Sujeit...         None
# 874734         Encaminhada à publicação. Publicação Inicial e...         None
# 874104                                  Recebimento pelo(a) CDC.          925
# 873280               Apensação desta proposição ao PL 4348/2024.          925
#
#                            descricao_situacao  \
# id_tramitacao
# 771001                                   None
# 771000                                   None
# 770999         Transformado em Norma Jurídica
# 770998                                   None
# 770997                                   None
# ...                                       ...
# 875892                                   None
# 875352                                   None
# 874734                                   None
# 874104                 Tramitando em Conjunto
# 873280                 Tramitando em Conjunto
#
#                                         regime  \
# id_tramitacao
# 771001               Urgência (Art. 155, RICD)
# 771000               Urgência (Art. 155, RICD)
# 770999               Urgência (Art. 155, RICD)
# 770998               Urgência (Art. 155, RICD)
# 770997               Urgência (Art. 155, RICD)
# ...                                        ...
# 875892         Ordinário (Art. 151, III, RICD)
# 875352         Ordinário (Art. 151, III, RICD)
# 874734         Ordinário (Art. 151, III, RICD)
# 874104         Ordinário (Art. 151, III, RICD)
# 873280         Ordinário (Art. 151, III, RICD)
#
#                                                       apreciacao  \
# id_tramitacao
# 771001               Proposição Sujeita à Apreciação do Plenário
# 771000               Proposição Sujeita à Apreciação do Plenário
# 770999               Proposição Sujeita à Apreciação do Plenário
# 770998               Proposição Sujeita à Apreciação do Plenário
# 770997               Proposição Sujeita à Apreciação do Plenário
# ...                                                          ...
# 875892         Proposição Sujeita à Apreciação Conclusiva pel...
# 875352         Proposição Sujeita à Apreciação Conclusiva pel...
# 874734         Proposição Sujeita à Apreciação Conclusiva pel...
# 874104         Proposição Sujeita à Apreciação Conclusiva pel...
# 873280         Proposição Sujeita à Apreciação Conclusiva pel...
#
#               cod_tipo_tramitacao  \
# id_tramitacao
# 771001                        100
# 771000                        500
# 770999                        110
# 770998                        604
# 770997                        500
# ...                           ...
# 875892                        100
# 875352                        129
# 874734                        604
# 874104                        500
# 873280                        106
#
#                                                        uri_orgao  \
# id_tramitacao
# 771001         https://dadosabertos.camara.leg.br/api/v2/orga...
# 771000         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770999         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770998         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770997         https://dadosabertos.camara.leg.br/api/v2/orga...
# ...                                                          ...
# 875892         https://dadosabertos.camara.leg.br/api/v2/orga...
# 875352         https://dadosabertos.camara.leg.br/api/v2/orga...
# 874734         https://dadosabertos.camara.leg.br/api/v2/orga...
# 874104         https://dadosabertos.camara.leg.br/api/v2/orga...
# 873280         https://dadosabertos.camara.leg.br/api/v2/orga...
#
#                cod_tipo_orgao  \
# id_tramitacao
# 771001                     26
# 771000                  12000
# 770999                      1
# 770998                  12000
# 770997                      2
# ...                       ...
# 875892                      1
# 875352                      1
# 874734                  12000
# 874104                      2
# 873280                      2
#
#                                                       nome_orgao  \
# id_tramitacao
# 771001                                                  Plenário
# 771000         Seção de Registro e Controle de Análise da Pro...
# 770999                     Mesa Diretora da Câmara dos Deputados
# 770998                      COORDENAÇÃO DE COMISSÕES PERMANENTES
# 770997                     Comissão de Desenvolvimento Econômico
# ...                                                          ...
# 875892                     Mesa Diretora da Câmara dos Deputados
# 875352                     Mesa Diretora da Câmara dos Deputados
# 874734                      COORDENAÇÃO DE COMISSÕES PERMANENTES
# 874104                          Comissão de Defesa do Consumidor
# 873280                          Comissão de Defesa do Consumidor
#
#                                   tipo_orgao
# id_tramitacao
# 771001                      Plenário Virtual
# 771000         Órgão da Câmara dos Deputados
# 770999                     Comissão Diretora
# 770998         Órgão da Câmara dos Deputados
# 770997                   Comissão Permanente
# ...                                      ...
# 875892                     Comissão Diretora
# 875352                     Comissão Diretora
# 874734         Órgão da Câmara dos Deputados
# 874104                   Comissão Permanente
# 873280                   Comissão Permanente
#
# [387132 rows x 16 columns]

# %% [markdown]
# Reorganizamos as colunas:

# %%
house_tram_expanded_df = house_tram_expanded_df[[
    # Dados da tramitação
    'sequencia',
    'data_hora',
    'cod_tipo_tramitacao',
    'descricao_tramitacao',
    # Dados da proposição
    'id_proposicao',
    'prop_label',
    # Situação
    'cod_situacao',
    'descricao_situacao',
    # Órgao
    'sigla_orgao',
    'nome_orgao',
    'cod_tipo_orgao',
    'tipo_orgao',
    'uri_orgao',
    # Outros
    'despacho',
    'regime',
    'apreciacao',
]]
house_tram_expanded_df
# Out:
#                sequencia           data_hora cod_tipo_tramitacao  \
# id_tramitacao
# 771001                 1 2004-05-13 14:41:00                 100
# 771000                 6 2004-05-14 10:46:00                 500
# 770999                12 2004-05-28 11:08:00                 110
# 770998                17 2004-06-01 00:00:00                 604
# 770997                18 2004-06-02 09:45:00                 500
# ...                  ...                 ...                 ...
# 875892                 2 2025-07-02 14:10:00                 100
# 875352                 8 2025-08-29 14:45:00                 129
# 874734                14 2025-09-02 00:00:00                 604
# 874104                15 2025-09-04 11:18:00                 500
# 873280                16 2025-09-04 11:22:00                 106
#
#                      descricao_tramitacao  id_proposicao    prop_label  \
# id_tramitacao
# 771001         Apresentação de Proposição         253500  PL 2597/2024
# 771000                        Recebimento         253500  PL 2597/2024
# 770999                       Distribuição         253500  PL 2597/2024
# 770998           Publicação de Proposição         253500  PL 2597/2024
# 770997                        Recebimento         253500  PL 2597/2024
# ...                                   ...            ...           ...
# 875892         Apresentação de Proposição        2531284  PL 3194/2025
# 875352              Despacho de Apensação        2531284  PL 3194/2025
# 874734           Publicação de Proposição        2531284  PL 3194/2025
# 874104                        Recebimento        2531284  PL 3194/2025
# 873280                          Apensação        2531284  PL 3194/2025
#
#               cod_situacao              descricao_situacao sigla_orgao  \
# id_tramitacao
# 771001                None                            None        PLEN
# 771000                None                            None  SECAP(SGM)
# 770999                1140  Transformado em Norma Jurídica        MESA
# 770998                None                            None         CCP
# 770997                None                            None         CDE
# ...                    ...                             ...         ...
# 875892                None                            None        MESA
# 875352                None                            None        MESA
# 874734                None                            None         CCP
# 874104                 925          Tramitando em Conjunto         CDC
# 873280                 925          Tramitando em Conjunto         CDC
#
#                                                       nome_orgao  \
# id_tramitacao
# 771001                                                  Plenário
# 771000         Seção de Registro e Controle de Análise da Pro...
# 770999                     Mesa Diretora da Câmara dos Deputados
# 770998                      COORDENAÇÃO DE COMISSÕES PERMANENTES
# 770997                     Comissão de Desenvolvimento Econômico
# ...                                                          ...
# 875892                     Mesa Diretora da Câmara dos Deputados
# 875352                     Mesa Diretora da Câmara dos Deputados
# 874734                      COORDENAÇÃO DE COMISSÕES PERMANENTES
# 874104                          Comissão de Defesa do Consumidor
# 873280                          Comissão de Defesa do Consumidor
#
#                cod_tipo_orgao                     tipo_orgao  \
# id_tramitacao
# 771001                     26               Plenário Virtual
# 771000                  12000  Órgão da Câmara dos Deputados
# 770999                      1              Comissão Diretora
# 770998                  12000  Órgão da Câmara dos Deputados
# 770997                      2            Comissão Permanente
# ...                       ...                            ...
# 875892                      1              Comissão Diretora
# 875352                      1              Comissão Diretora
# 874734                  12000  Órgão da Câmara dos Deputados
# 874104                      2            Comissão Permanente
# 873280                      2            Comissão Permanente
#
#                                                        uri_orgao  \
# id_tramitacao
# 771001         https://dadosabertos.camara.leg.br/api/v2/orga...
# 771000         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770999         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770998         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770997         https://dadosabertos.camara.leg.br/api/v2/orga...
# ...                                                          ...
# 875892         https://dadosabertos.camara.leg.br/api/v2/orga...
# 875352         https://dadosabertos.camara.leg.br/api/v2/orga...
# 874734         https://dadosabertos.camara.leg.br/api/v2/orga...
# 874104         https://dadosabertos.camara.leg.br/api/v2/orga...
# 873280         https://dadosabertos.camara.leg.br/api/v2/orga...
#
#                                                         despacho  \
# id_tramitacao
# 771001         Apresentação do Projeto de Lei pelo Dep. José ...
# 771000                                    Recebimento pela MESA.
# 770999         Às Comissões de Desenvolvimento Econômico, Ind...
# 770998         Encaminhada à publicação. Publicação Inicial n...
# 770997                                   Recebimento pela CDEIC.
# ...                                                          ...
# 875892         Apresentação do PL n. 3194/2025 (Projeto de Le...
# 875352         Apense-se à(ao) PL-4348/2024.Proposição Sujeit...
# 874734         Encaminhada à publicação. Publicação Inicial e...
# 874104                                  Recebimento pelo(a) CDC.
# 873280               Apensação desta proposição ao PL 4348/2024.
#
#                                         regime  \
# id_tramitacao
# 771001               Urgência (Art. 155, RICD)
# 771000               Urgência (Art. 155, RICD)
# 770999               Urgência (Art. 155, RICD)
# 770998               Urgência (Art. 155, RICD)
# 770997               Urgência (Art. 155, RICD)
# ...                                        ...
# 875892         Ordinário (Art. 151, III, RICD)
# 875352         Ordinário (Art. 151, III, RICD)
# 874734         Ordinário (Art. 151, III, RICD)
# 874104         Ordinário (Art. 151, III, RICD)
# 873280         Ordinário (Art. 151, III, RICD)
#
#                                                       apreciacao
# id_tramitacao
# 771001               Proposição Sujeita à Apreciação do Plenário
# 771000               Proposição Sujeita à Apreciação do Plenário
# 770999               Proposição Sujeita à Apreciação do Plenário
# 770998               Proposição Sujeita à Apreciação do Plenário
# 770997               Proposição Sujeita à Apreciação do Plenário
# ...                                                          ...
# 875892         Proposição Sujeita à Apreciação Conclusiva pel...
# 875352         Proposição Sujeita à Apreciação Conclusiva pel...
# 874734         Proposição Sujeita à Apreciação Conclusiva pel...
# 874104         Proposição Sujeita à Apreciação Conclusiva pel...
# 873280         Proposição Sujeita à Apreciação Conclusiva pel...
#
# [387132 rows x 16 columns]

# %% [markdown]
# Por análise manual, identificamos alguns códigos de órgãos que não são relevantes para nosso estudo ou que podem ser erros de digitação.

# %%
orgao_code_excludes = [
    70_000,  # Sociedade Civil (provavelmente erro)
    12_000,  # Órgãos burocráticos da Câmara (só tarefas protocolares)
    40_000,  # Senado Federal; veremos lá e não cá
    10,      # Grupos de trabalho, nada relevante
    11,      # Conselho de Ética da Câmara; irrelevante para o escopo deste trabalho
]

# %% [markdown]
# Então excluímo-nos da tabela.

# %%
house_tram_expanded_filtered_df = house_tram_expanded_df[
    (~house_tram_expanded_df['cod_tipo_orgao'].isin(orgao_code_excludes))
].sort_values(['id_proposicao', 'sequencia'])
house_tram_expanded_filtered_df
# Out:
#                sequencia           data_hora cod_tipo_tramitacao  \
# id_tramitacao
# 771001                 1 2004-05-13 14:41:00                 100
# 770999                12 2004-05-28 11:08:00                 110
# 770997                18 2004-06-02 09:45:00                 500
# 770996                19 2004-06-08 11:34:00                 320
# 770995                20 2004-06-08 11:37:00                 350
# ...                  ...                 ...                 ...
# 876366                 1 2024-04-15 00:00:00                1050
# 875892                 2 2025-07-02 14:10:00                 100
# 875352                 8 2025-08-29 14:45:00                 129
# 874104                15 2025-09-04 11:18:00                 500
# 873280                16 2025-09-04 11:22:00                 106
#
#                                     descricao_tramitacao  id_proposicao  \
# id_tramitacao
# 771001                        Apresentação de Proposição         253500
# 770999                                      Distribuição         253500
# 770997                                       Recebimento         253500
# 770996                          Designação de Relator(a)         253500
# 770995                                 Abertura de Prazo         253500
# ...                                                  ...            ...
# 876366         Notificacao para Publicação Intermediária        2531284
# 875892                        Apresentação de Proposição        2531284
# 875352                             Despacho de Apensação        2531284
# 874104                                       Recebimento        2531284
# 873280                                         Apensação        2531284
#
#                  prop_label cod_situacao              descricao_situacao  \
# id_tramitacao
# 771001         PL 2597/2024         None                            None
# 770999         PL 2597/2024         1140  Transformado em Norma Jurídica
# 770997         PL 2597/2024         None                            None
# 770996         PL 2597/2024         None                            None
# 770995         PL 2597/2024         None                            None
# ...                     ...          ...                             ...
# 876366         PL 3194/2025          925          Tramitando em Conjunto
# 875892         PL 3194/2025         None                            None
# 875352         PL 3194/2025         None                            None
# 874104         PL 3194/2025          925          Tramitando em Conjunto
# 873280         PL 3194/2025          925          Tramitando em Conjunto
#
#               sigla_orgao                             nome_orgao  \
# id_tramitacao
# 771001               PLEN                               Plenário
# 770999               MESA  Mesa Diretora da Câmara dos Deputados
# 770997                CDE  Comissão de Desenvolvimento Econômico
# 770996                CDE  Comissão de Desenvolvimento Econômico
# 770995                CDE  Comissão de Desenvolvimento Econômico
# ...                   ...                                    ...
# 876366                CDC       Comissão de Defesa do Consumidor
# 875892               MESA  Mesa Diretora da Câmara dos Deputados
# 875352               MESA  Mesa Diretora da Câmara dos Deputados
# 874104                CDC       Comissão de Defesa do Consumidor
# 873280                CDC       Comissão de Defesa do Consumidor
#
#                cod_tipo_orgao           tipo_orgao  \
# id_tramitacao
# 771001                     26     Plenário Virtual
# 770999                      1    Comissão Diretora
# 770997                      2  Comissão Permanente
# 770996                      2  Comissão Permanente
# 770995                      2  Comissão Permanente
# ...                       ...                  ...
# 876366                      2  Comissão Permanente
# 875892                      1    Comissão Diretora
# 875352                      1    Comissão Diretora
# 874104                      2  Comissão Permanente
# 873280                      2  Comissão Permanente
#
#                                                        uri_orgao  \
# id_tramitacao
# 771001         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770999         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770997         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770996         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770995         https://dadosabertos.camara.leg.br/api/v2/orga...
# ...                                                          ...
# 876366         https://dadosabertos.camara.leg.br/api/v2/orga...
# 875892         https://dadosabertos.camara.leg.br/api/v2/orga...
# 875352         https://dadosabertos.camara.leg.br/api/v2/orga...
# 874104         https://dadosabertos.camara.leg.br/api/v2/orga...
# 873280         https://dadosabertos.camara.leg.br/api/v2/orga...
#
#                                                         despacho  \
# id_tramitacao
# 771001         Apresentação do Projeto de Lei pelo Dep. José ...
# 770999         Às Comissões de Desenvolvimento Econômico, Ind...
# 770997                                   Recebimento pela CDEIC.
# 770996           Designado Relator, Dep. Ronaldo Dimas (PSDB-TO)
# 770995         Abertura de Prazo para Emendas ao Projeto a pa...
# ...                                                          ...
# 876366         Designado Relator, Dep. Márcio Marinho (REPUBL...
# 875892         Apresentação do PL n. 3194/2025 (Projeto de Le...
# 875352         Apense-se à(ao) PL-4348/2024.Proposição Sujeit...
# 874104                                  Recebimento pelo(a) CDC.
# 873280               Apensação desta proposição ao PL 4348/2024.
#
#                                         regime  \
# id_tramitacao
# 771001               Urgência (Art. 155, RICD)
# 770999               Urgência (Art. 155, RICD)
# 770997               Urgência (Art. 155, RICD)
# 770996               Urgência (Art. 155, RICD)
# 770995               Urgência (Art. 155, RICD)
# ...                                        ...
# 876366         Ordinário (Art. 151, III, RICD)
# 875892         Ordinário (Art. 151, III, RICD)
# 875352         Ordinário (Art. 151, III, RICD)
# 874104         Ordinário (Art. 151, III, RICD)
# 873280         Ordinário (Art. 151, III, RICD)
#
#                                                       apreciacao
# id_tramitacao
# 771001               Proposição Sujeita à Apreciação do Plenário
# 770999               Proposição Sujeita à Apreciação do Plenário
# 770997               Proposição Sujeita à Apreciação do Plenário
# 770996               Proposição Sujeita à Apreciação do Plenário
# 770995               Proposição Sujeita à Apreciação do Plenário
# ...                                                          ...
# 876366         Proposição Sujeita à Apreciação Conclusiva pel...
# 875892         Proposição Sujeita à Apreciação Conclusiva pel...
# 875352         Proposição Sujeita à Apreciação Conclusiva pel...
# 874104         Proposição Sujeita à Apreciação Conclusiva pel...
# 873280         Proposição Sujeita à Apreciação Conclusiva pel...
#
# [343108 rows x 16 columns]

# %% [markdown]
# A função abaixo extrai um `Event`, onde possível, para cada fileira da tabela de tramitações da Câmara

# %%
def house_row_to_event(row: pd.Series) -> Event | None:
    # apresentado
    if row['cod_tipo_tramitacao'] == '100':
        return Event.APRESENTADO

    # distribuído
    # Retirei porque não faz diferença para isso e ser recebido na comissão
    # if row['cod_tipo_tramitacao'] == '110':
    #     return Event.DISTRIBUIDO

    # recebido em comissão
    if row['cod_tipo_tramitacao'] == '500' and row['tipo_orgao'].startswith('Comissão'):
        return Event.RECEBIDO_COMISSAO

    # designado relator em comissão
    if row['cod_tipo_tramitacao'] == '320' and row['tipo_orgao'].startswith('Comissão'):
        return Event.DESIGNADO_RELATOR_COMISSAO

    # retirado de pauta em comissão
    if row['cod_tipo_tramitacao'] == '250' and row['tipo_orgao'].startswith('Comissão'):
        return Event.RETIRADO_PAUTA_COMISSAO

    if row['cod_tipo_tramitacao'] == '250':
        return Event.RETIRADO_PAUTA_PLENARIO

    # aprovada urgência
    if row['cod_tipo_tramitacao'] == '196':
        return Event.APROVADA_URGENCIA

    # designado relator em plenário
    if row['cod_tipo_tramitacao'] == '320' and row['sigla_orgao'] == 'PLEN':
        return Event.DESIGNADO_RELATOR_PLENARIO

    # remetido
    if row['cod_tipo_tramitacao'] == '128':
        return Event.REMETIDO_AO_SENADO
    if row['cod_tipo_tramitacao'] == '609':
        return Event.REMETIDO_A_SANCAO
    if row['cod_tipo_tramitacao'] == '608':
        return Event.REMETIDO_A_PROMULGACAO
    if row['cod_tipo_tramitacao'] == '100' and row['despacho'].startswith('Remessa ao Senado Federal'):
        return Event.REMETIDO_AO_SENADO
    if row['cod_tipo_tramitacao'] == '1243' and row['despacho'].startswith('A matéria vai à sanção'):
        return Event.REMETIDO_A_SANCAO

    # aprovado em plenário
    if row['cod_tipo_tramitacao'] == '1235':
        return Event.APROVADO_PLENARIO

    # rejeitado em plenário
    if row['cod_tipo_tramitacao'] == '1236':
        return Event.REJEITADO_PLENARIO

    # arquivado
    if row['cod_tipo_tramitacao'] in ['502', '1024']:
        return Event.ARQUIVADO

    # desarquivado
    if row['cod_tipo_tramitacao'] == '503':
        return Event.DESARQUIVADO

# %% [markdown]
# Tomamos a tabela de tramitações, aplicamos a função acima para criar a coluna `event`, e excluímos as fileiras em que não foi atribuído valor para essa coluna. Agora temos uma tabela próxima da estrutura que queremos:

# %%
df_with_events = house_tram_expanded_filtered_df.copy()
df_with_events['event'] = df_with_events.apply(house_row_to_event, axis=1)
df_with_events = df_with_events[df_with_events['event'].notnull()]
df_with_events
# Out:
#                sequencia           data_hora cod_tipo_tramitacao  \
# id_tramitacao
# 771001                 1 2004-05-13 14:41:00                 100
# 770997                18 2004-06-02 09:45:00                 500
# 770996                19 2004-06-08 11:34:00                 320
# 770979                43 2007-01-31 00:00:00                 502
# 770976                47 2007-06-14 10:48:00                 320
# ...                  ...                 ...                 ...
# 756876                14 2025-09-03 12:18:00                 500
# 875891                 2 2025-06-30 15:09:00                 100
# 874103                14 2025-09-03 15:47:00                 500
# 875892                 2 2025-07-02 14:10:00                 100
# 874104                15 2025-09-04 11:18:00                 500
#
#                      descricao_tramitacao  id_proposicao    prop_label  \
# id_tramitacao
# 771001         Apresentação de Proposição         253500  PL 2597/2024
# 770997                        Recebimento         253500  PL 2597/2024
# 770996           Designação de Relator(a)         253500  PL 2597/2024
# 770979                       Arquivamento         253500  PL 2597/2024
# 770976           Designação de Relator(a)         253500  PL 2597/2024
# ...                                   ...            ...           ...
# 756876                        Recebimento        2529128  PL 3114/2025
# 875891         Apresentação de Proposição        2529248  PL 3127/2025
# 874103                        Recebimento        2529248  PL 3127/2025
# 875892         Apresentação de Proposição        2531284  PL 3194/2025
# 874104                        Recebimento        2531284  PL 3194/2025
#
#               cod_situacao              descricao_situacao sigla_orgao  \
# id_tramitacao
# 771001                None                            None        PLEN
# 770997                None                            None         CDE
# 770996                None                            None         CDE
# 770979                1140  Transformado em Norma Jurídica        MESA
# 770976                None                            None         CDE
# ...                    ...                             ...         ...
# 756876                 925          Tramitando em Conjunto      CSAUDE
# 875891                None                            None        MESA
# 874103                 925          Tramitando em Conjunto     CMULHER
# 875892                None                            None        MESA
# 874104                 925          Tramitando em Conjunto         CDC
#
#                                               nome_orgao  cod_tipo_orgao  \
# id_tramitacao
# 771001                                          Plenário              26
# 770997             Comissão de Desenvolvimento Econômico               2
# 770996             Comissão de Desenvolvimento Econômico               2
# 770979             Mesa Diretora da Câmara dos Deputados               1
# 770976             Comissão de Desenvolvimento Econômico               2
# ...                                                  ...             ...
# 756876                                 Comissão de Saúde               2
# 875891             Mesa Diretora da Câmara dos Deputados               1
# 874103         Comissão de Defesa dos Direitos da Mulher               2
# 875892             Mesa Diretora da Câmara dos Deputados               1
# 874104                  Comissão de Defesa do Consumidor               2
#
#                         tipo_orgao  \
# id_tramitacao
# 771001            Plenário Virtual
# 770997         Comissão Permanente
# 770996         Comissão Permanente
# 770979           Comissão Diretora
# 770976         Comissão Permanente
# ...                            ...
# 756876         Comissão Permanente
# 875891           Comissão Diretora
# 874103         Comissão Permanente
# 875892           Comissão Diretora
# 874104         Comissão Permanente
#
#                                                        uri_orgao  \
# id_tramitacao
# 771001         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770997         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770996         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770979         https://dadosabertos.camara.leg.br/api/v2/orga...
# 770976         https://dadosabertos.camara.leg.br/api/v2/orga...
# ...                                                          ...
# 756876         https://dadosabertos.camara.leg.br/api/v2/orga...
# 875891         https://dadosabertos.camara.leg.br/api/v2/orga...
# 874103         https://dadosabertos.camara.leg.br/api/v2/orga...
# 875892         https://dadosabertos.camara.leg.br/api/v2/orga...
# 874104         https://dadosabertos.camara.leg.br/api/v2/orga...
#
#                                                         despacho  \
# id_tramitacao
# 771001         Apresentação do Projeto de Lei pelo Dep. José ...
# 770997                                   Recebimento pela CDEIC.
# 770996           Designado Relator, Dep. Ronaldo Dimas (PSDB-TO)
# 770979         Arquivado nos termos do Artigo 105 do Regiment...
# 770976          Designado Relator, Dep. Leandro Sampaio (PPS-RJ)
# ...                                                          ...
# 756876                               Recebimento pelo(a) CSAUDE.
# 875891         Apresentação do PL n. 3127/2025 (Projeto de Le...
# 874103                                 Recebimento pela CMULHER.
# 875892         Apresentação do PL n. 3194/2025 (Projeto de Le...
# 874104                                  Recebimento pelo(a) CDC.
#
#                                         regime  \
# id_tramitacao
# 771001               Urgência (Art. 155, RICD)
# 770997               Urgência (Art. 155, RICD)
# 770996               Urgência (Art. 155, RICD)
# 770979               Urgência (Art. 155, RICD)
# 770976               Urgência (Art. 155, RICD)
# ...                                        ...
# 756876         Prioridade (Art. 151, II, RICD)
# 875891         Ordinário (Art. 151, III, RICD)
# 874103         Ordinário (Art. 151, III, RICD)
# 875892         Ordinário (Art. 151, III, RICD)
# 874104         Ordinário (Art. 151, III, RICD)
#
#                                                       apreciacao  \
# id_tramitacao
# 771001               Proposição Sujeita à Apreciação do Plenário
# 770997               Proposição Sujeita à Apreciação do Plenário
# 770996               Proposição Sujeita à Apreciação do Plenário
# 770979               Proposição Sujeita à Apreciação do Plenário
# 770976               Proposição Sujeita à Apreciação do Plenário
# ...                                                          ...
# 756876               Proposição Sujeita à Apreciação do Plenário
# 875891         Proposição Sujeita à Apreciação Conclusiva pel...
# 874103         Proposição Sujeita à Apreciação Conclusiva pel...
# 875892         Proposição Sujeita à Apreciação Conclusiva pel...
# 874104         Proposição Sujeita à Apreciação Conclusiva pel...
#
#                                           event
# id_tramitacao
# 771001                        Event.APRESENTADO
# 770997                  Event.RECEBIDO_COMISSAO
# 770996         Event.DESIGNADO_RELATOR_COMISSAO
# 770979                          Event.ARQUIVADO
# 770976         Event.DESIGNADO_RELATOR_COMISSAO
# ...                                         ...
# 756876                  Event.RECEBIDO_COMISSAO
# 875891                        Event.APRESENTADO
# 874103                  Event.RECEBIDO_COMISSAO
# 875892                        Event.APRESENTADO
# 874104                  Event.RECEBIDO_COMISSAO
#
# [114998 rows x 17 columns]

# %% [markdown]
# Disso podemos descartar as colunas que não desejamos e renomear desta forma:
#
# * `id_proposicao`: Como antes;
# * `prop_label`: Como antes;
# * `event_ts`: O timestamp do evento;
# * `event`: O valor atribuído de `Event`;
# * `event_loc`: A sigla do local do evento (comissões, plenário) conforme nos dados originais.

# %%
house_event_df = (df_with_events[['id_proposicao', 'prop_label', 'data_hora', 'event', 'sigla_orgao']]
    .sort_values(['data_hora', 'id_proposicao'])
    .reset_index(drop=True)
    .rename(columns={
        'data_hora': 'event_ts',
        'sigla_orgao': 'event_loc',
    }))
house_event_df
# Out:
#         id_proposicao    prop_label            event_ts  \
# 0              253500  PL 2597/2024 2004-05-13 14:41:00
# 1              253500  PL 2597/2024 2004-06-02 09:45:00
# 2              253500  PL 2597/2024 2004-06-08 11:34:00
# 3              257161  PL 2159/2021 2004-06-22 14:57:00
# 4              259111  PL 2105/2019 2004-06-23 18:06:00
# ...               ...           ...                 ...
# 114993        2322659  PL 1203/2022 2025-09-24 15:47:00
# 114994        2429969  PL 1425/2024 2025-09-24 15:47:00
# 114995        2320831  PL 1078/2022 2025-09-24 16:30:00
# 114996        2391466  PL 4719/2023 2025-09-24 16:52:00
# 114997        2418319   PL 353/2024 2025-09-24 16:52:00
#
#                                    event event_loc
# 0                      Event.APRESENTADO      PLEN
# 1                Event.RECEBIDO_COMISSAO       CDE
# 2       Event.DESIGNADO_RELATOR_COMISSAO       CDE
# 3                Event.RECEBIDO_COMISSAO     CMADS
# 4                      Event.APRESENTADO      PLEN
# ...                                  ...       ...
# 114993  Event.DESIGNADO_RELATOR_COMISSAO      CASP
# 114994  Event.DESIGNADO_RELATOR_COMISSAO      CASP
# 114995  Event.DESIGNADO_RELATOR_COMISSAO        CE
# 114996  Event.DESIGNADO_RELATOR_COMISSAO       CFT
# 114997  Event.DESIGNADO_RELATOR_COMISSAO       CFT
#
# [114998 rows x 5 columns]

# %% [markdown]
# ### 2.2.2. Senado Federal

# %% [markdown]
# Vamos agora gerar uma tabela de eventos para o Senado, de estrutura semelhante àquela da Câmara, para ser concatenada a ela, gerando assim uma tabela unificada de eventos para as proposições.
#
# A única diferença da tabela do Senado para a tabela da Câmara é que, em vez da colunas `id_proposicao` e `prop_label`, ela terá as colunas `id_processo` e `proc_label`, seguindo a nomenclatura do Senado. Isso será usado para fundir as duas tabelas depois.
#
# No caso do Senado, a tarefa de extrair os eventos é um pouco mais complexa, porque o Senado não tem uma tabela unificada de tramitações como a Câmara (ao menos não disponível ao público). Na verdade, dentro de cada registro de processo, há uma série de payloads aninhados que trazem informações sobre os andamentos, despachos etc. Outras tramitações são encontradas nos informes legislativos e outras tabelas. Temos então que buscar os eventos um por um.

# %% [markdown]
# A apresentação de um processo no Senado consta na data de apresentação do documento:

# %%
senate_apres_df = senate_procs_df[
    senate_procs_df['documento_data_apresentacao'].notna()
].reset_index()[[
    'id_processo',
    'identificacao',
    'documento_data_apresentacao',
]].rename(
    columns={
        'identificacao': 'proc_label',
        'documento_data_apresentacao': 'event_ts',
    }
)
senate_apres_df['event'] = Event.APRESENTADO
senate_apres_df['event_loc'] = "PLEN"
senate_apres_df
# Out:
#       id_processo    proc_label   event_ts              event event_loc
# 0         7711601   PL 547/2019 2019-01-04  Event.APRESENTADO      PLEN
# 1         7711690    PEC 2/2019 2019-02-06  Event.APRESENTADO      PLEN
# 2         7712043   PL 557/2019 2019-02-06  Event.APRESENTADO      PLEN
# 3         7714029   PL 577/2019 2019-02-05  Event.APRESENTADO      PLEN
# 4         7714041   PL 581/2019 2019-02-05  Event.APRESENTADO      PLEN
# ...           ...           ...        ...                ...       ...
# 2782      8776824  PL 3337/2024 2024-12-17  Event.APRESENTADO      PLEN
# 2783      8779434  PL 3817/2024 2024-12-18  Event.APRESENTADO      PLEN
# 2784      8779801  PLP 210/2024 2024-12-18  Event.APRESENTADO      PLEN
# 2785      8781192  PL 4614/2024 2024-12-19  Event.APRESENTADO      PLEN
# 2786      8781234  PL 3802/2024 2024-12-19  Event.APRESENTADO      PLEN
#
# [2787 rows x 5 columns]

# %% [markdown]
# Extraímos dos Informes Legislativos as designações de relator em comissão.

# %%
senate_desig_df = senate_inf_df[
    senate_inf_df['descricao'].str.match(r"^(re)?distribuído", case=False)
    & senate_inf_df['id_processo'].isin(senate_procs_df.index)
].reset_index()[['id_processo', 'data_informe', 'colegiado_sigla']].join(
    senate_procs_df[['identificacao']], on="id_processo"
).rename(
    columns={
        'identificacao': 'proc_label',
        'data_informe': 'event_ts',
        'colegiado_sigla': 'event_loc',
    }
)
senate_desig_df['event'] = Event.DESIGNADO_RELATOR_COMISSAO
senate_desig_df
# Out:
#       id_processo   event_ts event_loc    proc_label  \
# 0         7714045 2019-02-27       CAE   PLP 16/2019
# 1         7718136 2021-09-22       CAE   PLP 26/2019
# 2         7720504 2019-03-22       CDH   PL 938/2019
# 3         7723055 2021-10-15        CE  PL 1265/2019
# 4         7714051 2019-03-14       CAE   PL 579/2019
# ...           ...        ...       ...           ...
# 1854      8737346 2024-12-02       CMO   PLN 38/2024
# 1855      8762115 2024-12-06       CMO   PLN 39/2024
# 1856      8682454 2024-08-06       CMO   PLN 16/2024
# 1857      8726711 2024-12-02       CMO   PLN 28/2024
# 1858      8701679 2024-10-08       CCJ   PLP 68/2024
#
#                                  event
# 0     Event.DESIGNADO_RELATOR_COMISSAO
# 1     Event.DESIGNADO_RELATOR_COMISSAO
# 2     Event.DESIGNADO_RELATOR_COMISSAO
# 3     Event.DESIGNADO_RELATOR_COMISSAO
# 4     Event.DESIGNADO_RELATOR_COMISSAO
# ...                                ...
# 1854  Event.DESIGNADO_RELATOR_COMISSAO
# 1855  Event.DESIGNADO_RELATOR_COMISSAO
# 1856  Event.DESIGNADO_RELATOR_COMISSAO
# 1857  Event.DESIGNADO_RELATOR_COMISSAO
# 1858  Event.DESIGNADO_RELATOR_COMISSAO
#
# [1859 rows x 5 columns]

# %% [markdown]
# E das unidades de destino, a recepção em Comissão:

# %%
senate_rec_com_df = (
    senate_unid_df.join(senate_desp_df, on="id_despacho", lsuffix="_unid", rsuffix="_desp")
        .join(senate_prov_df, on="id_providencia", lsuffix="_unid", rsuffix="_prov")
        .join(senate_procs_df[['identificacao']], on="id_processo")
        .reset_index()
)[[
    'id_processo_unid',
    'identificacao',
    'data_despacho',
    'colegiado_sigla',
]].rename(
    columns={
        'id_processo_unid': 'id_processo',
    'identificacao': 'proc_label',
    'data_despacho': 'event_ts',
    'colegiado_sigla': 'event_loc',
    }
)
senate_rec_com_df['event'] = Event.RECEBIDO_COMISSAO
senate_rec_com_df
# Out:
#         id_processo    proc_label   event_ts event_loc  \
# 0           7711601   PL 547/2019 2019-02-07       CAE
# 1           7711690    PEC 2/2019 2019-02-07       CCJ
# 2           7712043   PL 557/2019 2019-02-07       CRE
# 3           7714029   PL 577/2019 2019-02-11       CAE
# 4           7714041   PL 581/2019 2022-12-15      PLEN
# ...             ...           ...        ...       ...
# 130088      8555503  PL 4764/2023 2023-10-17      CCDD
# 130089      8565029  PL 2245/2023 2023-11-14       CAE
# 130090      8575549  PL 5289/2023 2023-11-13       CDR
# 130091      8511486     PL 3/2023 2023-08-17       CDH
# 130092      8565029  PL 2245/2023 2023-10-17       CAE
#
#                           event
# 0       Event.RECEBIDO_COMISSAO
# 1       Event.RECEBIDO_COMISSAO
# 2       Event.RECEBIDO_COMISSAO
# 3       Event.RECEBIDO_COMISSAO
# 4       Event.RECEBIDO_COMISSAO
# ...                         ...
# 130088  Event.RECEBIDO_COMISSAO
# 130089  Event.RECEBIDO_COMISSAO
# 130090  Event.RECEBIDO_COMISSAO
# 130091  Event.RECEBIDO_COMISSAO
# 130092  Event.RECEBIDO_COMISSAO
#
# [130093 rows x 5 columns]

# %% [markdown]
# Da mesma forma, extraímos as aprovações de urgência, retiradas de pauta, designações de relator em plenário. Isso obtemos com busca por palavra-chave no corpo do informe legislativo.

# %%
desig_relat_re = re.compile(r'(?i)^designad.*relator')
senate_desig_plen_df = senate_inf_df[
    senate_inf_df['colegiado_sigla'].eq("PLEN")
    & senate_inf_df['descricao'].str.match(desig_relat_re)
].reset_index()[[
    'id_processo',
    'data_informe',
    'colegiado_sigla',
]].join(senate_procs_df[['identificacao']], on='id_processo').rename(
    columns={
        'data_informe': 'event_ts',
        'colegiado_sigla': 'event_loc',
        'identificacao': 'proc_label',
    }
)
senate_desig_plen_df['event'] = Event.DESIGNADO_RELATOR_PLENARIO
senate_desig_plen_df
# Out:
#      id_processo   event_ts event_loc    proc_label  \
# 0        7872006 2022-12-21      PLEN   PL 509/2020
# 1        7749718 2021-03-11      PLEN  PL 2706/2019
# 2        7778390 2023-05-02      PLEN  PL 3983/2019
# 3        7815156 2022-05-02      PLEN  PL 5189/2019
# 4        7833514 2023-05-10      PLEN  PLP 245/2019
# ..           ...        ...       ...           ...
# 292      8779801 2024-12-19      PLEN  PLP 210/2024
# 293      8670267 2024-05-27      PLEN  PL 1213/2024
# 294      8663585 2024-07-09      PLEN  PL 1847/2024
# 295      8746458 2024-11-12      PLEN  PLP 175/2024
# 296      8672212 2024-06-03      PLEN   PL 914/2024
#
#                                 event
# 0    Event.DESIGNADO_RELATOR_PLENARIO
# 1    Event.DESIGNADO_RELATOR_PLENARIO
# 2    Event.DESIGNADO_RELATOR_PLENARIO
# 3    Event.DESIGNADO_RELATOR_PLENARIO
# 4    Event.DESIGNADO_RELATOR_PLENARIO
# ..                                ...
# 292  Event.DESIGNADO_RELATOR_PLENARIO
# 293  Event.DESIGNADO_RELATOR_PLENARIO
# 294  Event.DESIGNADO_RELATOR_PLENARIO
# 295  Event.DESIGNADO_RELATOR_PLENARIO
# 296  Event.DESIGNADO_RELATOR_PLENARIO
#
# [297 rows x 5 columns]

# %%
aprov_urgencia_re = re.compile(r'(?i)aprovado[^\n]*urgência')
senate_aprov_urg_df = senate_inf_df[
    senate_inf_df['descricao'].str.contains(aprov_urgencia_re)
].reset_index()[[
    'id_processo',
    'data_informe',
    'colegiado_sigla',
]].join(senate_procs_df[['identificacao']], on='id_processo').rename(
    columns={
        'data_informe': 'event_ts',
        'colegiado_sigla': 'event_loc',
        'identificacao': 'proc_label',
    }
)
senate_aprov_urg_df['event'] = Event.APROVADA_URGENCIA
senate_aprov_urg_df
# Out:
#      id_processo   event_ts event_loc    proc_label                    event
# 0        7718337 2023-05-30      PLEN   PL 776/2019  Event.APROVADA_URGENCIA
# 1        7720308 2023-07-05      PLEN   PLP 41/2019  Event.APROVADA_URGENCIA
# 2        7716769 2020-02-18      PLEN   PLP 19/2019  Event.APROVADA_URGENCIA
# 3        7837621 2023-08-29      PLEN  PLP 257/2019  Event.APROVADA_URGENCIA
# 4        7859496 2020-05-25      None  MPV 918/2020  Event.APROVADA_URGENCIA
# ..           ...        ...       ...           ...                      ...
# 337      8718106 2024-09-17      PLEN  PL 1725/2024  Event.APROVADA_URGENCIA
# 338      8758266 2024-12-11       CMA  PL 3944/2024  Event.APROVADA_URGENCIA
# 339      8672212 2024-06-04      PLEN   PL 914/2024  Event.APROVADA_URGENCIA
# 340      8542290 2023-11-29      PLEN  PL 3626/2023  Event.APROVADA_URGENCIA
# 341      8701679 2024-12-11       CCJ   PLP 68/2024  Event.APROVADA_URGENCIA
#
# [342 rows x 5 columns]

# %%
retir_pauta_re = re.compile(r'(?i)a matéria (foi|é) retirada de pauta')
senate_retir_paut_df = senate_inf_df[
    senate_inf_df['colegiado_sigla'].ne("PLEN")
    & senate_inf_df['descricao'].str.contains(retir_pauta_re)
].reset_index()[[
    'id_processo',
    'data_informe',
    'colegiado_sigla',
]].join(senate_procs_df[['identificacao']], on='id_processo').rename(
    columns={
        'data_informe': 'event_ts',
        'colegiado_sigla': 'event_loc',
        'identificacao': 'proc_label',
    }
)
senate_retir_paut_df['event'] = Event.RETIRADO_PAUTA_COMISSAO
senate_retir_paut_df
# Out:
# /tmp/ipykernel_3260007/1411710615.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & senate_inf_df['descricao'].str.contains(retir_pauta_re)
#      id_processo   event_ts event_loc    proc_label  \
# 0        7718146 2020-02-12       CCJ   PL 711/2019
# 1        7714289 2019-05-21       CAE   PL 583/2019
# 2        7711690 2019-05-08       CCJ    PEC 2/2019
# 3        7714029 2019-04-17       CAS   PL 577/2019
# 4        7714289 2019-05-21       CAE   PL 583/2019
# ..           ...        ...       ...           ...
# 219      8658538 2024-09-17        CE  PL 1711/2024
# 220      8658538 2024-09-03        CE  PL 1711/2024
# 221      8488172 2023-09-27       CDH  PL 3324/2023
# 222      8574430 2024-03-13       CAS  PL 3466/2023
# 223      8693052 2024-09-17        CE  PL 2729/2024
#
#                              event
# 0    Event.RETIRADO_PAUTA_COMISSAO
# 1    Event.RETIRADO_PAUTA_COMISSAO
# 2    Event.RETIRADO_PAUTA_COMISSAO
# 3    Event.RETIRADO_PAUTA_COMISSAO
# 4    Event.RETIRADO_PAUTA_COMISSAO
# ..                             ...
# 219  Event.RETIRADO_PAUTA_COMISSAO
# 220  Event.RETIRADO_PAUTA_COMISSAO
# 221  Event.RETIRADO_PAUTA_COMISSAO
# 222  Event.RETIRADO_PAUTA_COMISSAO
# 223  Event.RETIRADO_PAUTA_COMISSAO
#
# [224 rows x 5 columns]

# %% [markdown]
# E finalmente as situações iniciadas conforme indicado nos informes legislativos

# %%
def map_sig(sig):
    if pd.isna(sig):
        return sig
        
    if sig.startswith("APRVD"):
        return Event.APROVADO_PLENARIO
    if sig == "ARQVD":
        return Event.ARQUIVADO
    if sig == "RTPA":
        return Event.RETIRADO_PAUTA_PLENARIO
    if sig == "RMSAN":
        return Event.REMETIDO_A_SANCAO
    if sig == "RMCD":
        return Event.REMETIDO_A_CAMARA
    if sig == "RMPRO":
        return Event.REMETIDO_A_PROMULGACAO
    if sig == "DESARQLEG":
        return Event.DESARQUIVADO
    if sig.startswith("RJTDA"):
        return Event.REJEITADO_PLENARIO

senate_other_df = senate_inf_df.join(
    senate_inf_df['sigla_situacao_iniciada'].apply(map_sig).rename('event')  # type: ignore
)

senate_other_df = senate_other_df[senate_other_df['event'].notna()][[
    'id_processo',
    'data_informe',
    'event'
]].join(
    senate_procs_df[['identificacao']],
    on='id_processo'
).rename(columns={
    'data_informe': 'event_ts',
    'identificacao': 'proc_label',
})
# Na tabela original pode ser Plenário, Mesa ou vazio, mas tudo isso é relativo ao plenário
senate_other_df['event_loc'] = "PLEN"
senate_other_df
# Out:
#                         id_processo   event_ts                    event  \
# id_informe_legislativo
# 1965                        7712043 2022-12-16  Event.REMETIDO_A_CAMARA
# 1967                        7714041 2022-12-20  Event.REMETIDO_A_CAMARA
# 1970                        7714055 2023-10-04  Event.REMETIDO_A_CAMARA
# 1979                        7717212 2022-12-22          Event.ARQUIVADO
# 1984                        7717482 2023-04-13  Event.REMETIDO_A_CAMARA
# ...                             ...        ...                      ...
# 315055                      8708174 2024-08-29  Event.APROVADO_PLENARIO
# 315106                      8726711 2024-12-19  Event.REMETIDO_A_SANCAO
# 315571                      8671111 2024-05-29  Event.APROVADO_PLENARIO
# 315688                      8726711 2024-12-18  Event.APROVADO_PLENARIO
# 315896                      8701679 2024-12-16  Event.REMETIDO_A_CAMARA
#
#                          proc_label event_loc
# id_informe_legislativo
# 1965                    PL 557/2019      PLEN
# 1967                    PL 581/2019      PLEN
# 1970                    PL 580/2019      PLEN
# 1979                    PL 634/2019      PLEN
# 1984                    PL 633/2019      PLEN
# ...                             ...       ...
# 315055                  PLN 25/2024      PLEN
# 315106                  PLN 28/2024      PLEN
# 315571                  PLN 13/2024      PLEN
# 315688                  PLN 28/2024      PLEN
# 315896                  PLP 68/2024      PLEN
#
# [3279 rows x 5 columns]

# %% [markdown]
# Construímos a tabela de eventos do Senado:

# %%
senate_event_df = pd.concat([
    senate_apres_df,
    senate_desig_df,
    senate_rec_com_df,
    senate_desig_plen_df,
    senate_aprov_urg_df,
    senate_retir_paut_df,
    senate_other_df,
])
senate_event_df
# Out:
#         id_processo   proc_label   event_ts                    event event_loc
# 0           7711601  PL 547/2019 2019-01-04        Event.APRESENTADO      PLEN
# 1           7711690   PEC 2/2019 2019-02-06        Event.APRESENTADO      PLEN
# 2           7712043  PL 557/2019 2019-02-06        Event.APRESENTADO      PLEN
# 3           7714029  PL 577/2019 2019-02-05        Event.APRESENTADO      PLEN
# 4           7714041  PL 581/2019 2019-02-05        Event.APRESENTADO      PLEN
# ...             ...          ...        ...                      ...       ...
# 315055      8708174  PLN 25/2024 2024-08-29  Event.APROVADO_PLENARIO      PLEN
# 315106      8726711  PLN 28/2024 2024-12-19  Event.REMETIDO_A_SANCAO      PLEN
# 315571      8671111  PLN 13/2024 2024-05-29  Event.APROVADO_PLENARIO      PLEN
# 315688      8726711  PLN 28/2024 2024-12-18  Event.APROVADO_PLENARIO      PLEN
# 315896      8701679  PLP 68/2024 2024-12-16  Event.REMETIDO_A_CAMARA      PLEN
#
# [138881 rows x 5 columns]

# %% [markdown]
# ### 2.2.3. Tabela conjunta

# %% [markdown]
# Agora criamos a tabela conjunta. Primeiros rotulamos cada fileira com a tabela original e concatenamos.
#
# As colunas `id_proposicao` e `id_processo` são temporariamente descartadas, e unificamos as colunas `*_label` para que sirvam como referencial comum.

# %%
senate_event_df['casa'] = "senado"
house_event_df['casa'] = "camara"

# %%
full_event_df = pd.concat([
    house_event_df.drop('id_proposicao', axis=1).rename(columns={'prop_label': 'label'}),
    senate_event_df.drop('id_processo', axis=1).rename(columns={'proc_label': 'label'})
], ignore_index=True).sort_values(['label', 'event_ts']).reset_index(drop=True)
full_event_df
# Out:
#                 label            event_ts                             event  \
# 0       MPV 1000/2020 2020-09-03 00:00:00                 Event.APRESENTADO
# 1       MPV 1000/2020 2020-09-03 10:57:00                 Event.APRESENTADO
# 2       MPV 1000/2020 2020-09-09 00:00:00           Event.RECEBIDO_COMISSAO
# 3       MPV 1000/2020 2020-09-09 00:00:00                 Event.APRESENTADO
# 4       MPV 1000/2020 2020-12-17 00:00:00  Event.DESIGNADO_RELATOR_PLENARIO
# ...               ...                 ...                               ...
# 253874     PLV 8/2023 2023-03-30 17:23:00                 Event.APRESENTADO
# 253875     PLV 9/2020 2020-04-29 22:15:00                 Event.APRESENTADO
# 253876     PLV 9/2021 2021-05-25 19:23:00                 Event.APRESENTADO
# 253877     PLV 9/2022 2022-05-11 17:23:00                 Event.APRESENTADO
# 253878     PLV 9/2023 2023-04-25 19:30:00                 Event.APRESENTADO
#
#         event_loc    casa
# 0            PLEN  senado
# 1            EXEC  camara
# 2            MESA  camara
# 3            MESA  camara
# 4            PLEN  camara
# ...           ...     ...
# 253874  MPV115222  camara
# 253875       PLEN  camara
# 253876       PLEN  camara
# 253877  MPV108021  camara
# 253878       PLEN  camara
#
# [253879 rows x 5 columns]

# %% [markdown]
# Vamos remover repetições _consecutivas_ do mesmo evento para a mesma proposição no mesmo lugar.

# %%
full_event_df = full_event_df[full_event_df[['label', 'event', 'casa']].ne(
    full_event_df[['label', 'event', 'casa']].shift()
).any(axis=1)].reset_index(drop=True)
full_event_df
# Out:
#                label            event_ts                             event  \
# 0      MPV 1000/2020 2020-09-03 00:00:00                 Event.APRESENTADO
# 1      MPV 1000/2020 2020-09-03 10:57:00                 Event.APRESENTADO
# 2      MPV 1000/2020 2020-09-09 00:00:00           Event.RECEBIDO_COMISSAO
# 3      MPV 1000/2020 2020-09-09 00:00:00                 Event.APRESENTADO
# 4      MPV 1000/2020 2020-12-17 00:00:00  Event.DESIGNADO_RELATOR_PLENARIO
# ...              ...                 ...                               ...
# 99990     PLV 8/2023 2023-03-30 17:23:00                 Event.APRESENTADO
# 99991     PLV 9/2020 2020-04-29 22:15:00                 Event.APRESENTADO
# 99992     PLV 9/2021 2021-05-25 19:23:00                 Event.APRESENTADO
# 99993     PLV 9/2022 2022-05-11 17:23:00                 Event.APRESENTADO
# 99994     PLV 9/2023 2023-04-25 19:30:00                 Event.APRESENTADO
#
#        event_loc    casa
# 0           PLEN  senado
# 1           EXEC  camara
# 2           MESA  camara
# 3           MESA  camara
# 4           PLEN  camara
# ...          ...     ...
# 99990  MPV115222  camara
# 99991       PLEN  camara
# 99992       PLEN  camara
# 99993  MPV108021  camara
# 99994       PLEN  camara
#
# [99995 rows x 5 columns]

# %% [markdown]
# Finalmente, atribuímos as tags dos vértices - que equivalem aos valores desprezados de `id_proposicao` e `id_processo`. Para qualquer proposição que tenha tramitado tanto na Câmara quanto no Senado, teremos ambas as tags naquela fileira de vento.

# %%
full_event_df = full_event_df.join(
    house_props_df.set_index('prop_label')['prop_tag'],
    on="label"
).join(
    senate_procs_df.set_index('identificacao')[['tag']].rename(columns={'tag': 'proc_tag'}),
    on="label",
)

# %%
full_event_df
# Out:
#                label            event_ts                             event  \
# 0      MPV 1000/2020 2020-09-03 00:00:00                 Event.APRESENTADO
# 1      MPV 1000/2020 2020-09-03 10:57:00                 Event.APRESENTADO
# 2      MPV 1000/2020 2020-09-09 00:00:00           Event.RECEBIDO_COMISSAO
# 3      MPV 1000/2020 2020-09-09 00:00:00                 Event.APRESENTADO
# 4      MPV 1000/2020 2020-12-17 00:00:00  Event.DESIGNADO_RELATOR_PLENARIO
# ...              ...                 ...                               ...
# 99990     PLV 8/2023 2023-03-30 17:23:00                 Event.APRESENTADO
# 99991     PLV 9/2020 2020-04-29 22:15:00                 Event.APRESENTADO
# 99992     PLV 9/2021 2021-05-25 19:23:00                 Event.APRESENTADO
# 99993     PLV 9/2022 2022-05-11 17:23:00                 Event.APRESENTADO
# 99994     PLV 9/2023 2023-04-25 19:30:00                 Event.APRESENTADO
#
#        event_loc    casa    prop_tag    proc_tag
# 0           PLEN  senado  CP:2262062  SP:7979012
# 1           EXEC  camara  CP:2262062  SP:7979012
# 2           MESA  camara  CP:2262062  SP:7979012
# 3           MESA  camara  CP:2262062  SP:7979012
# 4           PLEN  camara  CP:2262062  SP:7979012
# ...          ...     ...         ...         ...
# 99990  MPV115222  camara  CP:2354532         NaN
# 99991       PLEN  camara  CP:2250966         NaN
# 99992       PLEN  camara  CP:2284649         NaN
# 99993  MPV108021  camara  CP:2322707         NaN
# 99994       PLEN  camara  CP:2358303         NaN
#
# [100038 rows x 7 columns]

# %% [markdown]
# Gravamos então para uso nas etapas seguintes.

# %%
full_event_df.to_pickle(ACCESS_DIR / 'full_event_df.pkl')

# %% [markdown]
# Fazemos uma breve inspeção.

# %%
event_summary_df = full_event_df.value_counts(['event', 'casa']).unstack()
event_summary_df
# Out:
# casa                               camara  senado
# event
# Event.APRESENTADO                 28958.0  2789.0
# Event.RECEBIDO_COMISSAO           31097.0  2313.0
# Event.DESIGNADO_RELATOR_COMISSAO  16615.0  1335.0
# Event.RETIRADO_PAUTA_COMISSAO      3904.0   165.0
# Event.RETIRADO_PAUTA_PLENARIO         NaN   192.0
# Event.APROVADA_URGENCIA            1425.0   333.0
# Event.DESIGNADO_RELATOR_PLENARIO   1610.0   294.0
# Event.REMETIDO_AO_SENADO            599.0     NaN
# Event.REMETIDO_A_CAMARA               NaN   741.0
# Event.REMETIDO_A_SANCAO             165.0   569.0
# Event.REMETIDO_A_PROMULGACAO          6.0     2.0
# Event.APROVADO_PLENARIO            1571.0  1280.0
# Event.REJEITADO_PLENARIO            767.0    15.0
# Event.ARQUIVADO                    2810.0   477.0
# Event.DESARQUIVADO                    3.0     3.0

# %%
full_event_df.groupby('casa').count()
# Out:
#         label  event_ts  event  event_loc  prop_tag  proc_tag
# casa
# camara  89530     89530  89530      89530     89530     12210
# senado  10508     10508  10508      10402      7621     10508
