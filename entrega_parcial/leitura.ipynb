# %% [markdown]
# Leitura da entrega parcial para levantar dados para o relatório final

# %%
import pandas as pd

nodes_df = pd.read_csv("outputs/nodes.csv")
edges_df = pd.read_csv("outputs/edges.csv")

# %%
nodes_df
# Out:
#       node_tag     prop_label prop_tag_house prop_tag_senate auth_tag_house  \
# 0         UP:0  MPV 1000/2020      P:2262062       P:7979012            NaN
# 1         UP:1  MPV 1001/2020      P:2262906       P:7983532            NaN
# 2         UP:2  MPV 1002/2020      P:2263381       P:7987460            NaN
# 3         UP:3  MPV 1003/2020      P:2263410       P:7987889            NaN
# 4         UP:4  MPV 1004/2020      P:2263411       P:7987895            NaN
# ...        ...            ...            ...             ...            ...
# 30188  UA:1859            NaN            NaN             NaN       O:102642
# 30189  UA:1860            NaN            NaN             NaN       O:102211
# 30190  UA:1861            NaN            NaN             NaN       O:102210
# 30191  UA:1862            NaN            NaN             NaN       O:102220
# 30192  UA:1863            NaN            NaN             NaN       O:102594
#
# ...

# %%
nodes_df['node_tag'].apply(lambda v: v.split(":")[0]).value_counts()
# Out:
# node_tag
# UP    28329
# UA     1864
# Name: count, dtype: int64

# %%
len(nodes_df)
# Out:
# 30193

# %%
len(edges_df)
# Out:
# 55294
